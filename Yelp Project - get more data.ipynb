# %%
import requests
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
### Chicago

url = "https://api.yelp.com/v3/businesses/search?location=Chicago&term=food&sort_by=best_match&limit=50"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer pwHDo59Fo12k22Lk_WuasrzxaxL8hsNtAwhNjXGdloxrVtRnBdQeTEFnwjvujVOmqFBMms-iDDXzwPcTNHDC_N4hqp013aFDRZaeA7JnzX2WSEkb0zZkq60_8IR4ZnYx"
}

response = requests.get(url, headers=headers)

# Parse JSON response
data = response.json()

# Normalize JSON data into table
dfChicago = pd.json_normalize(data["businesses"])
dfChicago = dfChicago[["id", "name", "alias", "price"]]

dfChicago.head()
# Out:
#                        id                         name  \
# 0  EYjyi_lytYaM1Ty7-kNKSg                      Phodega
# 1  87bmC0ZQ3pVU-wxRGtRkkQ  Sushi Plus Rotary Sushi Bar
# 2  ERYEi0job-Kwca1lkOcRhg                   NoodleBird
# 3  WA8Fuuv9zRfZ8H8YkeYxsg                   Aloha Eats
# 4  ruWJerAc9VW23GvegYddnQ                       Gaijin
#
#                                    alias price
# 0                        phodega-chicago    $$
# 1  sushi-plus-rotary-sushi-bar-chicago-3    $$
# 2                     noodlebird-chicago    $$
# 3                     aloha-eats-chicago    $$
# 4                         gaijin-chicago    $$

# %%
### New York

url = "https://api.yelp.com/v3/businesses/search?location=New%20York&term=food&sort_by=best_match&limit=50"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer pwHDo59Fo12k22Lk_WuasrzxaxL8hsNtAwhNjXGdloxrVtRnBdQeTEFnwjvujVOmqFBMms-iDDXzwPcTNHDC_N4hqp013aFDRZaeA7JnzX2WSEkb0zZkq60_8IR4ZnYx"
}

response = requests.get(url, headers=headers)


# Parse JSON response
data = response.json()

# Normalize JSON data into table
dfNY = pd.json_normalize(data["businesses"])
dfNY = dfNY[["id", "name", "alias", "price"]]

dfNY.head()
# Out:
#                        id                          name  \
# 0  IpBG_nY_opO9Zy-xNBEQCg     La Chilaquería - New York
# 1  gmFkWVROT8A90TAgq26C9A     Gotham Burger Social Club
# 2  ntiDPLkWm6GDLkYh0d2tBw                    5ive Spice
# 3  7r6NoHRjQKhkZlIcODZJwg  Howling Jeng Pop up Location
# 4  lSQ9xFnkph0CHctTbCp8mg             All’Antico Vinaio
#
#                                      alias price
# 0         la-chilaquería-new-york-new-york   NaN
# 1       gotham-burger-social-club-brooklyn   NaN
# 2                    5ive-spice-new-york-4    $$
# 3  howling-jeng-pop-up-location-brooklyn-3   NaN
# 4             all-antico-vinaio-new-york-3   NaN

# %%
### Miami

url = "https://api.yelp.com/v3/businesses/search?location=Miami&term=food&sort_by=best_match&limit=50"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer pwHDo59Fo12k22Lk_WuasrzxaxL8hsNtAwhNjXGdloxrVtRnBdQeTEFnwjvujVOmqFBMms-iDDXzwPcTNHDC_N4hqp013aFDRZaeA7JnzX2WSEkb0zZkq60_8IR4ZnYx"
}

response = requests.get(url, headers=headers)


# Parse JSON response
data = response.json()

# Normalize JSON data into table
dfMiami = pd.json_normalize(data["businesses"])
dfMiami = dfMiami[["id", "name", "alias", "price"]]

dfMiami.head()
# Out:
#                        id                                    name  \
# 0  UXHxLN3DcDGI57uDIfCuJA         Old's Havana Cuban Bar & Cocina
# 1  dS1PwKBd4ya9PG1d4cpkwQ       Tacos La Potranca & Cantina Miami
# 2  z1UW-zeI50bMEtGKFtrjmA  Grails Miami - Restaurant & Sports Bar
# 3  r3kHEOwaRiLn5fKnpVj1PA                 Hapa Kitchen and Eatery
# 4  zsJoDVfWfiA8pYMey2Ix2Q                               The B100M
#
#                                           alias price
# 0        olds-havana-cuban-bar-and-cocina-miami    $$
# 1     tacos-la-potranca-and-cantina-miami-doral   NaN
# 2  grails-miami-restaurant-and-sports-bar-miami    $$
# 3           hapa-kitchen-and-eatery-miami-beach   NaN
# 4                             the-b100m-miami-2   NaN

# %%
### Nashville

url = "https://api.yelp.com/v3/businesses/search?location=Nashville&term=food&sort_by=best_match&limit=50"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer pwHDo59Fo12k22Lk_WuasrzxaxL8hsNtAwhNjXGdloxrVtRnBdQeTEFnwjvujVOmqFBMms-iDDXzwPcTNHDC_N4hqp013aFDRZaeA7JnzX2WSEkb0zZkq60_8IR4ZnYx"
}

response = requests.get(url, headers=headers)


# Parse JSON response
data = response.json()

# Normalize JSON data into table
dfNashville = pd.json_normalize(data["businesses"])
dfNashville = dfNashville[["id", "name", "alias", "price"]]

dfNashville.head()
# Out:
#                        id                                          name  \
# 0  xlMQBBt9wrtahdqiRDcVSg                                  The Stillery
# 1  c3QxX3toWdqJnKQmmIliRQ                        The Twelve Thirty Club
# 2  Zx7n8mdt8OzLRXVzolXNhQ                                  Milk & Honey
# 3  0uL-FXY1M2UC12eZcFlTuQ                The Hampton Social - Nashville
# 4  GXFMD0Z4jEVZBCsbPf4CTQ  Hattie B’s Hot Chicken - Nashville - Midtown
#
#                                                alias price
# 0                             the-stillery-nashville    $$
# 1        honky-tonk-the-twelve-thirty-club-nashville   NaN
# 2                           milk-and-honey-nashville    $$
# 3           the-hampton-social-nashville-nashville-2    $$
# 4  hattie-b-s-hot-chicken-nashville-midtown-nashv...    $$

# %%
### San Francisco

url = "https://api.yelp.com/v3/businesses/search?location=San%20Francisco&term=food&sort_by=best_match&limit=50"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer pwHDo59Fo12k22Lk_WuasrzxaxL8hsNtAwhNjXGdloxrVtRnBdQeTEFnwjvujVOmqFBMms-iDDXzwPcTNHDC_N4hqp013aFDRZaeA7JnzX2WSEkb0zZkq60_8IR4ZnYx"
}

response = requests.get(url, headers=headers)


# Parse JSON response
data = response.json()

# Normalize JSON data into table
dfSF = pd.json_normalize(data["businesses"])
dfSF = dfSF[["id", "name", "alias", "price"]]

dfSF.head()
# Out:
#                        id            name                         alias price
# 0  RjPKqHk_FiegJVCekbJ4Mw             606           606-san-francisco-2   NaN
# 1  M0JTO3oyu6gxh1mfFjU-dA        San Tung      san-tung-san-francisco-2    $$
# 2  3o02eHV5vgN2lMY7OkgKHw    Little Aloha    little-aloha-san-francisco    $$
# 3  SUdC4LIL3huirbbBkHrhfw  The Laundromat  the-laundromat-san-francisco    $$
# 4  CQVKVFsloVhvZw-_O1nXPA         Sandy's          sandys-san-francisco    $$

# %%
### Denver

url = "https://api.yelp.com/v3/businesses/search?location=Denver&term=food&sort_by=best_match&limit=50"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer pwHDo59Fo12k22Lk_WuasrzxaxL8hsNtAwhNjXGdloxrVtRnBdQeTEFnwjvujVOmqFBMms-iDDXzwPcTNHDC_N4hqp013aFDRZaeA7JnzX2WSEkb0zZkq60_8IR4ZnYx"
}

response = requests.get(url, headers=headers)


# Parse JSON response
data = response.json()

# Normalize JSON data into table
dfDenver = pd.json_normalize(data["businesses"])
dfDenver = dfDenver[["id", "name", "alias", "price"]]

dfDenver.head()
# Out:
#                        id                                    name  \
# 0  6-MYTEofJo7jmdoTfuVIHA              Nana's Dim Sum & Dumplings
# 1  gagUrh3806qc5hZ14F0Odw  Denver Biscuit Company - Atomic Cowboy
# 2  A1oufYgb0ecwVPmfEDydSg                    Tokyo Premium Bakery
# 3  ZVRZablopgmiT7Z04DJAeA                             Cafe Miriam
# 4  RTvR4W7K-59xFFZAUTMTbQ                           Lucky Noodles
#
#                                          alias price
# 0           nanas-dim-sum-and-dumplings-denver   NaN
# 1  denver-biscuit-company-atomic-cowboy-denver    $$
# 2                  tokyo-premium-bakery-denver     $
# 3                           cafe-miriam-denver    $$
# 4                         lucky-noodles-denver    $$

# %%
### Charlotte

url = "https://api.yelp.com/v3/businesses/search?location=Charlotte&term=food&sort_by=best_match&limit=50"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer pwHDo59Fo12k22Lk_WuasrzxaxL8hsNtAwhNjXGdloxrVtRnBdQeTEFnwjvujVOmqFBMms-iDDXzwPcTNHDC_N4hqp013aFDRZaeA7JnzX2WSEkb0zZkq60_8IR4ZnYx"
}

response = requests.get(url, headers=headers)


# Parse JSON response
data = response.json()

# Normalize JSON data into table
dfCharlotte = pd.json_normalize(data["businesses"])
dfCharlotte = dfCharlotte[["id", "name", "alias", "price"]]

dfCharlotte.head()
# Out:
#                        id                     name  \
# 0  fxd1d4mep5j8XbE_DzecKA           Geno D's Pizza
# 1  dQOnVrU5O0tSY5ZS8t3ScA            Optimist Hall
# 2  LfShTjJgy8c3Z4LLM8UJJw     Queen City Roti Shop
# 3  tQHI7mjqQRFMnI9yUliaKA         Culinary Dropout
# 4  5Wz0LxipwPk27FwwPMUoiQ  Big Dave's Cheesesteaks
#
#                               alias price
# 0           geno-ds-pizza-charlotte    $$
# 1         optimist-hall-charlotte-3    $$
# 2    queen-city-roti-shop-charlotte   NaN
# 3      culinary-dropout-charlotte-4    $$
# 4  big-daves-cheesesteaks-charlotte    $$

# %%
### Houston

url = "https://api.yelp.com/v3/businesses/search?location=Houston&term=food&sort_by=best_match&limit=50"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer pwHDo59Fo12k22Lk_WuasrzxaxL8hsNtAwhNjXGdloxrVtRnBdQeTEFnwjvujVOmqFBMms-iDDXzwPcTNHDC_N4hqp013aFDRZaeA7JnzX2WSEkb0zZkq60_8IR4ZnYx"
}

response = requests.get(url, headers=headers)


# Parse JSON response
data = response.json()

# Normalize JSON data into table
dfHouston = pd.json_normalize(data["businesses"])
dfHouston = dfHouston[["id", "name", "alias", "price"]]

dfHouston.head()
# Out:
#                        id              name                        alias price
# 0  RoU8KznQMrRFcIjYVtdZMw      The Pit Room         the-pit-room-houston    $$
# 1  tGNsatvwwYGwb9sd14yKVQ   The Ginger Mule      the-ginger-mule-houston    $$
# 2  MeyUXf7jcgF-jeHnLZk3vg    Rooster & Rice     rooster-and-rice-houston    $$
# 3  Pv_I87b90U7nldtPUYSROg  Omi Japan Market  omi-japan-market-sugar-land   NaN
# 4  36laMC_BB-nr9CV8BDqk_g      The Rice Box       the-rice-box-houston-5    $$

# %%
### Phoenix

url = "https://api.yelp.com/v3/businesses/search?location=Phoenix&term=food&sort_by=best_match&limit=50"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer pwHDo59Fo12k22Lk_WuasrzxaxL8hsNtAwhNjXGdloxrVtRnBdQeTEFnwjvujVOmqFBMms-iDDXzwPcTNHDC_N4hqp013aFDRZaeA7JnzX2WSEkb0zZkq60_8IR4ZnYx"
}

response = requests.get(url, headers=headers)


# Parse JSON response
data = response.json()

# Normalize JSON data into table
dfPhoenix = pd.json_normalize(data["businesses"])
dfPhoenix = dfPhoenix[["id", "name", "alias", "price"]]

dfPhoenix.head()
# Out:
#                        id                             name  \
# 0  uHZDCuzXrgWBKrGP7JVPmA  The Bread & Honey House Arcadia
# 1  01S4FqBVG5BIPXWzImf9HA                    Copper & Sage
# 2  GCexynTlh3HHFsFliH42pg                        Doughbird
# 3  sfSVxFe48hWvNnqszU0nlQ                            Azlin
# 4  9IhbHwzXbhQmt3NtXe7kPA                           Tesota
#
#                                          alias price
# 0  the-bread-and-honey-house-arcadia-phoenix-4    $$
# 1                      copper-and-sage-phoenix   NaN
# 2                          doughbird-phoenix-7    $$
# 3                                azlin-phoenix   NaN
# 4                             tesota-phoenix-2   NaN

# %%
# Create URLs for each restaurnat in each city

cities = ["Chicago", "NY", "Miami", "Nashville", "SF", "Denver", "Charlotte", "Houston", "Phoenix"]

for city in cities:
    df = globals()[f"df{city}"]
    df['url'] = [0] * len(df)
    for i, j in df.iterrows():
        df.loc[i, 'url'] = f"https://www.yelp.com/biz/{df.loc[i, 'id']}#reviews"

    globals()[f"df{city}"] = df
# Out:
#                        id                         name  \
# 0  EYjyi_lytYaM1Ty7-kNKSg                      Phodega
# 1  87bmC0ZQ3pVU-wxRGtRkkQ  Sushi Plus Rotary Sushi Bar
# 2  ERYEi0job-Kwca1lkOcRhg                   NoodleBird
# 3  WA8Fuuv9zRfZ8H8YkeYxsg                   Aloha Eats
# 4  ruWJerAc9VW23GvegYddnQ                       Gaijin
#
#                                    alias price  \
# 0                        phodega-chicago    $$
# 1  sushi-plus-rotary-sushi-bar-chicago-3    $$
# 2                     noodlebird-chicago    $$
# 3                     aloha-eats-chicago    $$
# 4                         gaijin-chicago    $$
#
#                                                  url
# 0  https://www.yelp.com/biz/EYjyi_lytYaM1Ty7-kNKS...
# 1  https://www.yelp.com/biz/87bmC0ZQ3pVU-wxRGtRkk...
# 2  https://www.yelp.com/biz/ERYEi0job-Kwca1lkOcRh...
# 3  https://www.yelp.com/biz/WA8Fuuv9zRfZ8H8YkeYxs...
# 4  https://www.yelp.com/biz/ruWJerAc9VW23GvegYddn...

# %%
# create loop to get review data for all 500 businesses



for k in range(50):
    url = df.loc[k, 'url']
    response = requests.get(url)

    soup = BeautifulSoup(response.text, 'html.parser')
    reviews = soup.find('div', id ='reviews')
    
    if reviews is None:
        continue
    
    single_review = reviews.find('li', class_= 'y-css-1jp2syp')
    rating = single_review.find('div', class_= 'y-css-9tnml4')['aria-label']
    review_text = single_review.find('span', class_= 'raw__09f24__T4Ezm').text

    all_reviews = pd.Series(reviews.findAll('li', class_= 'y-css-1jp2syp', limit = 10))
    
    if all_reviews.size < 10:
        continue

    for m in range(10):
        r = all_reviews[m].find('div', class_= 'y-css-9tnml4')['aria-label']
        t = all_reviews[m].find('span', class_= 'raw__09f24__T4Ezm').text
        all_review_data.loc[m + 10*k] = [df.loc[k, 'id'], r, t]

# %%
# List of cities corresponding to the dataframe names
cities = ["Chicago", "NY", "Miami", "Nashville", "SF", "Denver", "Charlotte", "Houston", "Phoenix"]

# Initialize a dataframe to store all review data
all_review_data = pd.DataFrame(columns=['id', 'rating', 'review_text'])

# Loop through each dataframe
for city in cities:
    df = globals()[f"df{city}"]
    
    for k in range(len(df)):
        url = df.loc[k, 'url']
        response = requests.get(url)
        
        if response.status_code != 200:
            continue
        
        soup = BeautifulSoup(response.text, 'html.parser')
        reviews = soup.find('div', id='reviews')
        
        if reviews is None:
            continue
        
        single_review = reviews.find('li', class_='y-css-1jp2syp')
        
        if single_review is None:
            continue
        
        rating = single_review.find('div', class_='y-css-9tnml4')['aria-label']
        review_text = single_review.find('span', class_='raw__09f24__T4Ezm').text
        
        all_reviews = reviews.findAll('li', class_='y-css-1jp2syp', limit=10)
        
        if len(all_reviews) < 10:
            continue
        
        for m in range(10):
            r = all_reviews[m].find('div', class_='y-css-9tnml4')['aria-label']
            t = all_reviews[m].find('span', class_='raw__09f24__T4Ezm').text
            all_review_data = all_review_data.append({'id': df.loc[k, 'id'], 'rating': r, 'review_text': t}, ignore_index=True)
# Out:
# /var/folders/69/8k9ds_px2833z9tj2lp1n6y80000gn/T/ipykernel_17324/493942954.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_review_data = all_review_data.append({'id': df.loc[k, 'id'], 'rating': r, 'review_text': t}, ignore_index=True)
# /var/folders/69/8k9ds_px2833z9tj2lp1n6y80000gn/T/ipykernel_17324/493942954.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_review_data = all_review_data.append({'id': df.loc[k, 'id'], 'rating': r, 'review_text': t}, ignore_index=True)
# /var/folders/69/8k9ds_px2833z9tj2lp1n6y80000gn/T/ipykernel_17324/493942954.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
print(all_review_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           1100 non-null   object
#  1   rating       1100 non-null   object
#  2   review_text  1100 non-null   object
# dtypes: object(3)
# memory usage: 25.9+ KB
# None

# %%
print(dfNashville.loc[37])
# Out:
# id                                  1lDcde-lDKJRSCNpU0isIQ
# name                                                Lauter
# alias                                     lauter-nashville
# price                                                  NaN
# url      https://www.yelp.com/biz/1lDcde-lDKJRSCNpU0isI...
# Name: 37, dtype: object

# %%
print(all_review_data.loc[1099])
# Out:
# id                                        qorzlNqG3PG7zSAJpxkinA
# rating                                             4 star rating
# review_text    Overall, vibes are good and food is good. I wo...
# Name: 1099, dtype: object

# %%
first_loop = all_review_data
# Out:
# <bound method DataFrame.info of                           id         rating  \
# 0     EYjyi_lytYaM1Ty7-kNKSg  5 star rating
# 1     EYjyi_lytYaM1Ty7-kNKSg  3 star rating
# 2     EYjyi_lytYaM1Ty7-kNKSg  5 star rating
# 3     EYjyi_lytYaM1Ty7-kNKSg  5 star rating
# 4     EYjyi_lytYaM1Ty7-kNKSg  5 star rating
# ...                      ...            ...
# 1095  qorzlNqG3PG7zSAJpxkinA  5 star rating
# 1096  qorzlNqG3PG7zSAJpxkinA  5 star rating
# 1097  qorzlNqG3PG7zSAJpxkinA  5 star rating
# 1098  qorzlNqG3PG7zSAJpxkinA  5 star rating
# 1099  qorzlNqG3PG7zSAJpxkinA  4 star rating
#
#                                             review_text
# 0     Have you ever gotten food-high? I have. From P...
# 1     "Surely they'll have AC in there, right?" Wron...
# 2     Phodega has my ultimate comfort food: Hainan c...
# 3     Wow! This place has been on my list for awhile...
# 4     I've been twice now and everything I've gotten...
# ...                                                 ...
# ...

# %%
# List of cities corresponding to the dataframe names
cities = ["Nashville", "SF", "Denver", "Charlotte", "Houston", "Phoenix"]

# Initialize a dataframe to store all review data
all_review_data = pd.DataFrame(columns=['id', 'rating', 'review_text'])

# Loop through each dataframe
for city in cities:
    df = globals()[f"df{city}"]
    
    for k in range(len(df)):
        url = df.loc[k, 'url']
        response = requests.get(url)
        
        if response.status_code != 200:
            continue
        
        soup = BeautifulSoup(response.text, 'html.parser')
        reviews = soup.find('div', id='reviews')
        
        if reviews is None:
            continue
        
        single_review = reviews.find('li', class_='y-css-1jp2syp')
        
        if single_review is None:
            continue
        
        rating = single_review.find('div', class_='y-css-9tnml4')['aria-label']
        review_text = single_review.find('span', class_='raw__09f24__T4Ezm').text
        
        all_reviews = reviews.findAll('li', class_='y-css-1jp2syp', limit=10)
        
        if len(all_reviews) < 10:
            continue
        
        for m in range(10):
            r = all_reviews[m].find('div', class_='y-css-9tnml4')['aria-label']
            t = all_reviews[m].find('span', class_='raw__09f24__T4Ezm').text
            all_review_data = all_review_data.append({'id': df.loc[k, 'id'], 'rating': r, 'review_text': t}, ignore_index=True)
# Out:
# /var/folders/69/8k9ds_px2833z9tj2lp1n6y80000gn/T/ipykernel_17324/1693374931.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_review_data = all_review_data.append({'id': df.loc[k, 'id'], 'rating': r, 'review_text': t}, ignore_index=True)
# /var/folders/69/8k9ds_px2833z9tj2lp1n6y80000gn/T/ipykernel_17324/1693374931.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_review_data = all_review_data.append({'id': df.loc[k, 'id'], 'rating': r, 'review_text': t}, ignore_index=True)
# /var/folders/69/8k9ds_px2833z9tj2lp1n6y80000gn/T/ipykernel_17324/1693374931.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
all_review_data.info
# Out:
# <bound method DataFrame.info of                           id         rating  \
# 0     xlMQBBt9wrtahdqiRDcVSg  4 star rating
# 1     xlMQBBt9wrtahdqiRDcVSg  5 star rating
# 2     xlMQBBt9wrtahdqiRDcVSg  5 star rating
# 3     xlMQBBt9wrtahdqiRDcVSg  5 star rating
# 4     xlMQBBt9wrtahdqiRDcVSg  4 star rating
# ...                      ...            ...
# 2725  XRE8PgaxgJm5qiIqD_7eBQ  4 star rating
# 2726  XRE8PgaxgJm5qiIqD_7eBQ  5 star rating
# 2727  XRE8PgaxgJm5qiIqD_7eBQ  4 star rating
# 2728  XRE8PgaxgJm5qiIqD_7eBQ  5 star rating
# 2729  XRE8PgaxgJm5qiIqD_7eBQ  5 star rating
#
#                                             review_text
# 0     great food, great environment, great drinks, o...
# 1     Holy smokes. This place was great!! Great atmo...
# 2     Live music but not too loud!  Don't miss this ...
# 3     Food was excellent. Everything was served hot ...
# 4     Stopped here on a fairly busy Friday night and...
# ...                                                 ...
# ...

# %%
new_df = pd.concat([first_loop, all_review_data], ignore_index=True)

# %%
new_df.to_csv('other_cities_reviews.csv', index = False)
